# %% [markdown]
# <div style="text-align: center;">
#   <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="400">
#   </a>
# </div>

# %% [markdown]
# <h1 align=left><font size = 6>Lab: Comparative Analysis of Keras and PyTorch Models </font></h1>

# %% [markdown]
# <h5>Estimated time: 90 minutes</h5>

# %% [markdown]
# <h2>Objective</h2>
#
# After completing this lab, you will be able to:
# <ul>
#
# 1. Prepare data, load and evaluate Keras model.
# 2. Prepare data, load and evaluate PyTorch model.
# 3. Compute multiple performance metrics including accuracy, precision, recall, and f1-score.
# 4. Visualize receiver operating characteristic (ROC) curves.
# </ul>

# %% [markdown]
# ## Introduction
#
# In this lab, you will compare the performance of the Keras-based and the PyTorch based convolutional neural network (CNN) models using various evaluation metrics.  Common metrics include:
#
# - **Accuracy**: Measures how often the model is correct overall. A higher value means more total predictions are correct.
#
# - **Precision**: Measures how many predicted positives are actually correct. A higher value means fewer false positives (incorrectly predicted positives).
#
# - **Recall**: Measures how many real positives the model finds. A higher value means fewer false negatives (missed positive cases).
#
# - **F1 Score**: Tells us about the balance between precision and recall. A higher value means a better trade-off between precision and recall.
#
# - **ROC-AUC**: Measures the model’s ability to distinguish classes. A higher value reflects a model that can better distinguish between classes at all probability thresholds.
#
#
# For all these metrics, the model should aim for values as close to 1.0 (or 100%) as possible. Lower values indicate poorer model performance. There are exceptions for some metrics in other settings (like various loss functions, where lower is better), but for these standard classification metrics, higher is always better.

# %% [markdown]
# ## Table of Contents
# <font size = 3>
#
# 1. [Data download and extraction](#Data-download-and-extraction)
# 2. [Package installation](#Package-installation)
# 3. [Library imports and setup](#Library-imports-and-setup)
# 4. [Evaluation metrics](#Evaluation-metrics)
#     1. [Accuracy](#1.-Accuracy)
#     2. [Precision](#2.-Precision)
#     3. [Recall](#3.-Recall-(sensitivity-or-true-positive-rate))
#     4. [F1 score](#4.-F1-score)
#     5. [Confusion matrix](#5.-Confusion-matrix)
#     6. [ROC-AUC](#6.-ROC-AUC-(Receiver-operating-characteristic---Area-under-curve))
# 6. [Import the evaluation metrics](#Import-the-evaluation-metrics)
# 7. [Model paths and download](#Model-paths-and-download)
# 8. [Dataset path and parameters](#Dataset-path-and-parameters)
# 9. [PyTorch model evaluation and prediction](#PyTorch-model-evaluation-and-prediction)
# 10. [PyTorch metrics reporting](#PyTorch-metrics-reporting)
# 11. [Keras model evaluation and prediction](#Keras-model-evaluation-and-prediction)
# 12. [Keras metrics reporting](#Keras-metrics-reporting)
# 13. [ROC curve plotting](#ROC-curve-plotting)
# 14. [Comparing model performance](#Comparing-model-performance)
#
# </font>

# %% [markdown]
# ## Data download and extraction
# We begin by downloading the dataset for evaluation of the models.
# Here, you declare:
# 1. The dataset URL from where the dataset would be downloaded.
# 2. The dataset downloading primary function, based on `skillsnetwork` library.
# 3. The dataset fallback downloading function, based on regular `http` downloading functions.

# %%
# Download and extract the dataset (for Windows)
import os

print("Downloading dataset...")
# !powershell -Command "Invoke-WebRequest -Uri 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/4Z1fwRR295-1O3PMQBH6Dg/images-dataSAT.tar' -OutFile 'images-dataSAT.tar'"

print("Extracting dataset...")
# !tar -xvf images-dataSAT.tar

print("Dataset is ready!")
# Out:
# Downloading dataset...
# Extracting dataset...
# Dataset is ready!
# x images_dataSAT/
# x images_dataSAT/class_0_non_agri/
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_5902.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6074.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6246.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6247.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6248.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6249.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6497.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6589.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6592.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6749.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6763.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6764.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6846.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6935.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6936.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_6951.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7016.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7107.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7108.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7109.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7123.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7186.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7355.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7358.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7467.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7518.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7530.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7633.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7658.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7700.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7782.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_7872.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8044.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8178.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8297.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8670.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8718.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8728.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8850.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8900.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8903.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_8904.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9016.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9072.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9075.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9139.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9240.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9407.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9410.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9556.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9743.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9751.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9752.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9925.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250409T105701_N0511_R094_T31UDQ_20250409T173716.SAFE_9932.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0021.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0029.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0033.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0140.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0141.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0142.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0152.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0153.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0155.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0157.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0158.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0159.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0161.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0162.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0164.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0165.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0166.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0167.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0168.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0212.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0283.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0284.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0311.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0312.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0313.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0314.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0329.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0330.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0331.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0338.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0339.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0340.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0376.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0454.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0455.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0485.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0486.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0500.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0501.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0502.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0504.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0505.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0510.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0513.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0546.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0627.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0656.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0657.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0658.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0673.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0674.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0675.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0676.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0677.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0678.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0679.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0680.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0681.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0683.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0685.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0686.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0713.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0717.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0718.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0719.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0822.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0823.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0826.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0845.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0846.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0847.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0848.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0849.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0850.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0851.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0852.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0853.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0854.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0855.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0856.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0857.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0858.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0877.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0878.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0887.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0888.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0889.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_0890.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1001.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1007.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1015.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10172.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1020.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10202.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1021.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1022.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1023.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1024.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1025.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10255.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1026.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1027.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1028.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1029.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10290.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10306.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10332.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10336.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10374.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10375.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10417.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10418.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10443.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10462.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10477.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10486.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10504.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10546.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10547.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1058.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10589.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1059.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10590.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1061.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1062.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10648.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1065.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10676.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10677.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10726.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10731.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10784.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10853.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10858.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10862.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10895.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10909.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10911.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10928.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10941.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_10944.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11016.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11079.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11083.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11194.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11244.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11251.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11302.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11303.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11363.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11399.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11475.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1149.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11525.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11529.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11572.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1161.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11644.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11647.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11845.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11863.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11880.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11899.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11904.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1192.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1193.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1194.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1195.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11959.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1196.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_11975.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12002.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12003.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12018.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12052.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12053.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12133.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12174.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12175.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12245.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1230.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1231.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1234.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1235.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1236.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1237.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1238.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12413.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12534.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12556.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12578.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12617.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12660.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12680.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12788.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12789.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12891.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12911.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12921.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12922.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12923.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12926.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12928.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12929.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12933.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12951.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12961.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_12962.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13000.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13095.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13096.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13100.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13101.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13102.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13123.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13166.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13206.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1323.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13245.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13267.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13271.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13272.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13273.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13329.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1333.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1334.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13491.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13534.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13559.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1361.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1362.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1365.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1366.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1367.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13689.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13773.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13836.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13846.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13847.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13851.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13866.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13900.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13944.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_13997.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14016.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14017.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14020.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14109.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14129.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14172.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14189.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14190.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14191.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14192.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14193.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14194.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14196.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14249.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14282.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14300.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14332.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14362.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14363.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14364.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14366.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14370.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14401.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14535.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14538.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14539.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14540.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14542.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14562.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14577.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14608.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14609.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14704.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14705.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14708.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14709.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14710.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14711.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14712.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14713.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14714.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14779.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14793.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14810.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14875.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14876.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14877.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14880.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14882.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14883.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14884.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14885.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_14982.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15030.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1505.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15055.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15056.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15070.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1508.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15086.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15154.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15155.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15323.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15324.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15325.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15326.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15339.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1534.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1537.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1538.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15396.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15397.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15398.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15471.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15491.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15496.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15497.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15498.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15568.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15569.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15570.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15574.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15575.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15576.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15577.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15602.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15603.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15642.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15643.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1565.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15664.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15669.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_1567.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15670.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15671.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15743.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15745.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15746.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15747.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15749.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15750.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15751.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15752.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15760.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15813.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15814.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15835.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15836.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15837.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15840.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15845.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15864.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15908.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15916.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_15919.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_16095.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_16102.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_16113.jpg
# x images_dataSAT/class_0_non_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UPE_20250427T170513.SAFE_16259.jpg
# ...
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9539.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9553.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9564.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9565.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9607.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9609.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9620.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9622.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9625.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9633.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9639.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9655.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9697.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9701.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9733.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9735.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9744.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9799.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9815.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9816.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9833.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9857.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9876.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9900.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9901.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9908.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9909.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9924.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9928.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9956.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9958.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQB_20250427T170513.SAFE_9987.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0000.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0018.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0025.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0027.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0031.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0041.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0050.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0057.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0072.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0077.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0081.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0082.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0086.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0089.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0098.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0103.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0110.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0145.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0148.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0149.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0153.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0160.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0165.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0166.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0167.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0179.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0191.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0195.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0198.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0248.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0254.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0255.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0257.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0262.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0264.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0268.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0284.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0287.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0296.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0298.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0301.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0325.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0336.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0338.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0340.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0346.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0351.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0363.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0366.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0369.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0370.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0372.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0378.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0429.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0431.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0436.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0442.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0455.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0459.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0462.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0463.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0468.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0475.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0484.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0502.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0505.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0507.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0508.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0528.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0529.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0533.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0534.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0542.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0550.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0554.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0600.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0607.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0608.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0620.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0621.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0632.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0634.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0646.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0648.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0649.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0650.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0651.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0652.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0656.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0667.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0672.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0673.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0678.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0679.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0694.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0695.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0699.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0703.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0705.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0706.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0711.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0721.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0722.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0744.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0771.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0772.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0776.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0788.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0789.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0790.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0797.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0805.jpg
# x images_dataSAT/class_1_agri/tile_S2A_MSIL2A_20250427T101701_N0511_R065_T32UQD_20250427T170513.SAFE_0812.jpg

# %% [markdown]
# ## Package installation
#
# Install the required basic Python packages.

# %%
# %%time
# %%capture captured_output
# %pip install numpy==1.26
# %pip install matplotlib==3.9.2
# %pip install skillsnetwork
# Out:
# CPU times: total: 156 ms
# Wall time: 32.8 s

# %% [markdown]
# ### Install PyTorch library

# %%
# %%time
# %pip install torch==2.7.0
# Out:
# Collecting torch==2.7.0
#   Downloading torch-2.7.0-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Collecting filelock (from torch==2.7.0)
#   Downloading filelock-3.25.2-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0) (4.15.0)
# Collecting sympy>=1.13.3 (from torch==2.7.0)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.7.0)
#   Using cached networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0) (3.1.6)
# Collecting fsspec (from torch==2.7.0)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0) (82.0.1)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch==2.7.0)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from jinja2->torch==2.7.0) (3.0.3)
# Downloading torch-2.7.0-cp313-cp313-win_amd64.whl (212.5 MB)
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    ---------------------------------------- 2.4/212.5 MB 12.9 MB/s eta 0:00:17
#     --------------------------------------- 4.2/212.5 MB 12.7 MB/s eta 0:00:17
#    - -------------------------------------- 8.4/212.5 MB 14.0 MB/s eta 0:00:15
#    - -------------------------------------- 10.5/212.5 MB 13.9 MB/s eta 0:00:15
#    -- ------------------------------------- 12.1/212.5 MB 11.8 MB/s eta 0:00:18
#    --- ------------------------------------ 17.0/212.5 MB 13.8 MB/s eta 0:00:15
#    --- ------------------------------------ 21.2/212.5 MB 14.7 MB/s eta 0:00:14
#    ---- ----------------------------------- 24.1/212.5 MB 14.9 MB/s eta 0:00:13
#    ----- ---------------------------------- 27.8/212.5 MB 14.8 MB/s eta 0:00:13
#    ----- ---------------------------------- 29.4/212.5 MB 14.5 MB/s eta 0:00:13
#    ----- ---------------------------------- 31.7/212.5 MB 13.8 MB/s eta 0:00:14
#    ------ --------------------------------- 35.7/212.5 MB 14.5 MB/s eta 0:00:13
#    ------- -------------------------------- 39.8/212.5 MB 14.8 MB/s eta 0:00:12
#    ------- -------------------------------- 41.4/212.5 MB 14.2 MB/s eta 0:00:13
#    -------- ------------------------------- 46.4/212.5 MB 14.8 MB/s eta 0:00:12
#    --------- ------------------------------ 49.0/212.5 MB 14.6 MB/s eta 0:00:12
#    --------- ------------------------------ 52.4/212.5 MB 14.8 MB/s eta 0:00:11
#    ---------- ----------------------------- 55.6/212.5 MB 14.8 MB/s eta 0:00:11
#    ---------- ----------------------------- 57.7/212.5 MB 14.8 MB/s eta 0:00:11
#    ----------- ---------------------------- 59.5/212.5 MB 14.2 MB/s eta 0:00:11
#    ----------- ---------------------------- 61.9/212.5 MB 14.3 MB/s eta 0:00:11
#    ----------- ---------------------------- 61.9/212.5 MB 14.3 MB/s eta 0:00:11
#    ----------- ---------------------------- 61.9/212.5 MB 14.3 MB/s eta 0:00:11
#    ------------ --------------------------- 64.7/212.5 MB 13.1 MB/s eta 0:00:12
#    ------------- -------------------------- 70.3/212.5 MB 13.4 MB/s eta 0:00:11
#    -------------- ------------------------- 74.4/212.5 MB 13.8 MB/s eta 0:00:10
#    -------------- ------------------------- 75.2/212.5 MB 13.2 MB/s eta 0:00:11
#    -------------- ------------------------- 76.5/212.5 MB 13.0 MB/s eta 0:00:11
#    --------------- ------------------------ 79.7/212.5 MB 13.1 MB/s eta 0:00:11
#    --------------- ------------------------ 82.8/212.5 MB 13.2 MB/s eta 0:00:10
#    ---------------- ----------------------- 85.7/212.5 MB 13.1 MB/s eta 0:00:10
#    ---------------- ----------------------- 86.0/212.5 MB 13.1 MB/s eta 0:00:10
#    ---------------- ----------------------- 88.1/212.5 MB 12.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 91.2/212.5 MB 12.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 92.8/212.5 MB 12.6 MB/s eta 0:00:10
#    ------------------ --------------------- 98.0/212.5 MB 12.9 MB/s eta 0:00:09
#    ------------------ -------------------- 102.8/212.5 MB 13.2 MB/s eta 0:00:09
#    ------------------- ------------------- 107.0/212.5 MB 13.4 MB/s eta 0:00:08
#    -------------------- ------------------ 109.6/212.5 MB 13.4 MB/s eta 0:00:08
#    -------------------- ------------------ 113.8/212.5 MB 13.5 MB/s eta 0:00:08
#    --------------------- ----------------- 116.4/212.5 MB 13.5 MB/s eta 0:00:08
#    --------------------- ----------------- 119.8/212.5 MB 13.5 MB/s eta 0:00:07
#    ----------------------- --------------- 125.8/212.5 MB 13.9 MB/s eta 0:00:07
#    ----------------------- --------------- 130.3/212.5 MB 14.1 MB/s eta 0:00:06
#    ------------------------ -------------- 135.0/212.5 MB 14.2 MB/s eta 0:00:06
#    ------------------------- ------------- 141.6/212.5 MB 14.6 MB/s eta 0:00:05
#    ------------------------- ------------- 141.6/212.5 MB 14.6 MB/s eta 0:00:05
#    ------------------------- ------------- 141.6/212.5 MB 14.6 MB/s eta 0:00:05
#    ------------------------- ------------- 141.6/212.5 MB 14.6 MB/s eta 0:00:05
#    -------------------------- ------------ 142.1/212.5 MB 13.5 MB/s eta 0:00:06
#    -------------------------- ------------ 144.7/212.5 MB 13.5 MB/s eta 0:00:06
#    -------------------------- ------------ 146.0/212.5 MB 13.4 MB/s eta 0:00:05
#    --------------------------- ----------- 148.4/212.5 MB 13.4 MB/s eta 0:00:05
#    --------------------------- ----------- 152.0/212.5 MB 13.4 MB/s eta 0:00:05
#    ---------------------------- ---------- 154.9/212.5 MB 13.4 MB/s eta 0:00:05
#    ---------------------------- ---------- 156.2/212.5 MB 13.3 MB/s eta 0:00:05
#    ----------------------------- --------- 158.3/212.5 MB 13.2 MB/s eta 0:00:05
#    ----------------------------- --------- 161.7/212.5 MB 13.3 MB/s eta 0:00:04
#    ------------------------------ -------- 164.6/212.5 MB 13.3 MB/s eta 0:00:04
#    ------------------------------ -------- 167.8/212.5 MB 13.3 MB/s eta 0:00:04
#    ------------------------------- ------- 170.7/212.5 MB 13.3 MB/s eta 0:00:04
#    -------------------------------- ------ 174.9/212.5 MB 13.4 MB/s eta 0:00:03
#    -------------------------------- ------ 178.3/212.5 MB 13.5 MB/s eta 0:00:03
#    -------------------------------- ------ 178.3/212.5 MB 13.5 MB/s eta 0:00:03
#    --------------------------------- ----- 180.4/212.5 MB 13.2 MB/s eta 0:00:03
#    --------------------------------- ----- 182.2/212.5 MB 13.1 MB/s eta 0:00:03
#    --------------------------------- ----- 184.5/212.5 MB 13.1 MB/s eta 0:00:03
#    ---------------------------------- ---- 187.4/212.5 MB 13.1 MB/s eta 0:00:02
#    ----------------------------------- --- 192.2/212.5 MB 13.2 MB/s eta 0:00:02
#    ------------------------------------ -- 197.4/212.5 MB 13.4 MB/s eta 0:00:02
#    ------------------------------------- - 202.4/212.5 MB 13.5 MB/s eta 0:00:01
#    --------------------------------------  207.4/212.5 MB 13.7 MB/s eta 0:00:01
#    --------------------------------------  211.6/212.5 MB 13.8 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 13.8 MB/s eta 0:00:01
#    --------------------------------------  212.3/212.5 MB 13.8 MB/s eta 0:00:01
#    --------------------------------------- 212.5/212.5 MB 13.3 MB/s eta 0:00:00
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading filelock-3.25.2-py3-none-any.whl (26 kB)
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Installing collected packages: mpmath, sympy, networkx, fsspec, filelock, torch
#
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ---------------------------------------- 0/6 [mpmath]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------ --------------------------------- 1/6 [sympy]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    ------------- -------------------------- 2/6 [networkx]
#    -------------------- ------------------- 3/6 [fsspec]
#    -------------------- ------------------- 3/6 [fsspec]
#    -------------------- ------------------- 3/6 [fsspec]
#    -------------------- ------------------- 3/6 [fsspec]
#    -------------------- ------------------- 3/6 [fsspec]
#    -------------------------- ------------- 4/6 [filelock]
#    -------------------------- ------------- 4/6 [filelock]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    --------------------------------- ------ 5/6 [torch]
#    ---------------------------------------- 6/6 [torch]
#
# Successfully installed filelock-3.25.2 fsspec-2026.3.0 mpmath-1.3.0 networkx-3.6.1 sympy-1.14.0 torch-2.7.0
# Note: you may need to restart the kernel to use updated packages.
# CPU times: total: 453 ms
# Wall time: 2min 23s
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install PyTorch helper libraries

# %%
# %%time
# %pip install torchvision==0.22
# Out:
# Collecting torchvision==0.22
#   Downloading torchvision-0.22.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torchvision==0.22) (2.4.4)
# Requirement already satisfied: torch==2.7.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torchvision==0.22) (2.7.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torchvision==0.22) (12.2.0)
# Requirement already satisfied: filelock in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0->torchvision==0.22) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0->torchvision==0.22) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0->torchvision==0.22) (1.14.0)
# Requirement already satisfied: networkx in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0->torchvision==0.22) (3.6.1)
# Requirement already satisfied: jinja2 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0->torchvision==0.22) (3.1.6)
# Requirement already satisfied: fsspec in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0->torchvision==0.22) (2026.3.0)
# Requirement already satisfied: setuptools in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from torch==2.7.0->torchvision==0.22) (82.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from sympy>=1.13.3->torch==2.7.0->torchvision==0.22) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from jinja2->torch==2.7.0->torchvision==0.22) (3.0.3)
# Downloading torchvision-0.22.0-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------ --- 1.6/1.7 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 8.5 MB/s eta 0:00:00
# Installing collected packages: torchvision
# Successfully installed torchvision-0.22.0
# Note: you may need to restart the kernel to use updated packages.
# CPU times: total: 31.2 ms
# Wall time: 10.8 s
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install tensorflow library for Keras

# %%
# %%time
# %pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl.metadata (4.5 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from tensorflow) (26.0)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.80.0-cp313-cp313-win_amd64.whl.metadata (3.9 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Downloading keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from tensorflow) (2.4.4)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.46.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Downloading rich-14.3.4-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Downloading optree-0.19.0-cp313-cp313-win_amd64.whl.metadata (35 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading tensorflow-2.21.0-cp313-cp313-win_amd64.whl (351.2 MB)
#    ---------------------------------------- 0.0/351.2 MB ? eta -:--:--
#     --------------------------------------- 5.5/351.2 MB 34.4 MB/s eta 0:00:11
#    - -------------------------------------- 12.3/351.2 MB 31.6 MB/s eta 0:00:11
#    -- ------------------------------------- 20.2/351.2 MB 33.3 MB/s eta 0:00:10
#    -- ------------------------------------- 26.0/351.2 MB 32.2 MB/s eta 0:00:11
#    --- ------------------------------------ 33.6/351.2 MB 32.9 MB/s eta 0:00:10
#    ---- ----------------------------------- 40.6/351.2 MB 33.1 MB/s eta 0:00:10
#    ----- ---------------------------------- 48.2/351.2 MB 33.6 MB/s eta 0:00:10
#    ------ --------------------------------- 55.3/351.2 MB 33.9 MB/s eta 0:00:09
#    ------ --------------------------------- 59.8/351.2 MB 32.8 MB/s eta 0:00:09
#    ------- -------------------------------- 65.5/351.2 MB 31.9 MB/s eta 0:00:09
#    ------- -------------------------------- 69.5/351.2 MB 30.8 MB/s eta 0:00:10
#    -------- ------------------------------- 73.4/351.2 MB 29.7 MB/s eta 0:00:10
#    -------- ------------------------------- 77.3/351.2 MB 28.9 MB/s eta 0:00:10
#    --------- ------------------------------ 81.3/351.2 MB 28.0 MB/s eta 0:00:10
#    --------- ------------------------------ 84.9/351.2 MB 27.2 MB/s eta 0:00:10
#    ---------- ----------------------------- 89.1/351.2 MB 26.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 93.8/351.2 MB 26.5 MB/s eta 0:00:10
#    ----------- ---------------------------- 98.6/351.2 MB 26.2 MB/s eta 0:00:10
#    ----------- --------------------------- 103.3/351.2 MB 26.0 MB/s eta 0:00:10
#    ------------ -------------------------- 108.3/351.2 MB 25.9 MB/s eta 0:00:10
#    ------------ -------------------------- 112.7/351.2 MB 25.6 MB/s eta 0:00:10
#    ------------ -------------------------- 116.4/351.2 MB 25.3 MB/s eta 0:00:10
#    ------------- ------------------------- 120.6/351.2 MB 25.0 MB/s eta 0:00:10
#    ------------- ------------------------- 124.8/351.2 MB 24.8 MB/s eta 0:00:10
#    -------------- ------------------------ 129.0/351.2 MB 24.6 MB/s eta 0:00:10
#    -------------- ------------------------ 132.6/351.2 MB 24.3 MB/s eta 0:00:10
#    --------------- ----------------------- 136.6/351.2 MB 24.1 MB/s eta 0:00:09
#    --------------- ----------------------- 141.6/351.2 MB 24.0 MB/s eta 0:00:09
#    ---------------- ---------------------- 146.0/351.2 MB 23.9 MB/s eta 0:00:09
#    ---------------- ---------------------- 150.7/351.2 MB 23.9 MB/s eta 0:00:09
#    ----------------- --------------------- 155.5/351.2 MB 23.9 MB/s eta 0:00:09
#    ----------------- --------------------- 160.4/351.2 MB 23.8 MB/s eta 0:00:09
#    ------------------ -------------------- 165.7/351.2 MB 23.9 MB/s eta 0:00:08
#    ------------------ -------------------- 170.9/351.2 MB 23.9 MB/s eta 0:00:08
#    ------------------- ------------------- 174.6/351.2 MB 23.7 MB/s eta 0:00:08
#    ------------------- ------------------- 178.8/351.2 MB 23.6 MB/s eta 0:00:08
#    -------------------- ------------------ 183.0/351.2 MB 23.5 MB/s eta 0:00:08
#    -------------------- ------------------ 187.4/351.2 MB 23.4 MB/s eta 0:00:07
#    --------------------- ----------------- 191.9/351.2 MB 23.3 MB/s eta 0:00:07
#    --------------------- ----------------- 196.3/351.2 MB 23.3 MB/s eta 0:00:07
#    ---------------------- ---------------- 200.8/351.2 MB 23.2 MB/s eta 0:00:07
#    ---------------------- ---------------- 205.3/351.2 MB 23.1 MB/s eta 0:00:07
#    ----------------------- --------------- 209.2/351.2 MB 23.0 MB/s eta 0:00:07
#    ----------------------- --------------- 213.4/351.2 MB 22.9 MB/s eta 0:00:07
#    ------------------------ -------------- 218.6/351.2 MB 23.0 MB/s eta 0:00:06
#    ------------------------ -------------- 223.6/351.2 MB 23.0 MB/s eta 0:00:06
#    ------------------------ -------------- 224.4/351.2 MB 22.6 MB/s eta 0:00:06
#    ------------------------- ------------- 229.4/351.2 MB 22.6 MB/s eta 0:00:06
#    -------------------------- ------------ 234.9/351.2 MB 22.7 MB/s eta 0:00:06
#    -------------------------- ------------ 240.4/351.2 MB 22.7 MB/s eta 0:00:05
#    --------------------------- ----------- 246.2/351.2 MB 22.8 MB/s eta 0:00:05
#    --------------------------- ----------- 251.9/351.2 MB 22.9 MB/s eta 0:00:05
#    ---------------------------- ---------- 255.9/351.2 MB 22.9 MB/s eta 0:00:05
#    ---------------------------- ---------- 260.3/351.2 MB 22.8 MB/s eta 0:00:04
#    ----------------------------- --------- 265.6/351.2 MB 22.7 MB/s eta 0:00:04
#    ------------------------------ -------- 270.3/351.2 MB 22.6 MB/s eta 0:00:04
#    ------------------------------ -------- 274.7/351.2 MB 22.5 MB/s eta 0:00:04
#    ------------------------------- ------- 279.4/351.2 MB 22.3 MB/s eta 0:00:04
#    ------------------------------- ------- 284.4/351.2 MB 22.1 MB/s eta 0:00:04
#    -------------------------------- ------ 289.1/351.2 MB 22.1 MB/s eta 0:00:03
#    -------------------------------- ------ 293.9/351.2 MB 21.9 MB/s eta 0:00:03
#    --------------------------------- ----- 299.9/351.2 MB 21.9 MB/s eta 0:00:03
#    --------------------------------- ----- 304.1/351.2 MB 21.8 MB/s eta 0:00:03
#    --------------------------------- ----- 304.1/351.2 MB 21.8 MB/s eta 0:00:03
#    --------------------------------- ----- 304.1/351.2 MB 21.8 MB/s eta 0:00:03
#    --------------------------------- ----- 304.1/351.2 MB 21.8 MB/s eta 0:00:03
#    ---------------------------------- ---- 308.0/351.2 MB 20.5 MB/s eta 0:00:03
#    ---------------------------------- ---- 312.7/351.2 MB 20.4 MB/s eta 0:00:02
#    ----------------------------------- --- 316.4/351.2 MB 20.2 MB/s eta 0:00:02
#    ----------------------------------- --- 320.6/351.2 MB 20.1 MB/s eta 0:00:02
#    ------------------------------------ -- 324.8/351.2 MB 20.1 MB/s eta 0:00:02
#    ------------------------------------ -- 328.7/351.2 MB 19.9 MB/s eta 0:00:02
#    ------------------------------------ -- 333.2/351.2 MB 20.0 MB/s eta 0:00:01
#    ------------------------------------- - 337.6/351.2 MB 20.1 MB/s eta 0:00:01
#    --------------------------------------  342.4/351.2 MB 20.1 MB/s eta 0:00:01
#    --------------------------------------  347.1/351.2 MB 20.2 MB/s eta 0:00:01
#    --------------------------------------  351.0/351.2 MB 20.3 MB/s eta 0:00:01
#    --------------------------------------  351.0/351.2 MB 20.3 MB/s eta 0:00:01
#    --------------------------------------  351.0/351.2 MB 20.3 MB/s eta 0:00:01
#    --------------------------------------  351.0/351.2 MB 20.3 MB/s eta 0:00:01
#    --------------------------------------  351.0/351.2 MB 20.3 MB/s eta 0:00:01
#    --------------------------------------- 351.2/351.2 MB 18.9 MB/s eta 0:00:00
# Downloading grpcio-1.80.0-cp313-cp313-win_amd64.whl (4.9 MB)
#    ---------------------------------------- 0.0/4.9 MB ? eta -:--:--
#    ------------------------------------ --- 4.5/4.9 MB 20.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.9/4.9 MB 16.9 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp313-cp313-win_amd64.whl (2.9 MB)
#    ---------------------------------------- 0.0/2.9 MB ? eta -:--:--
#    ---------------------------------------- 2.9/2.9 MB 22.1 MB/s eta 0:00:00
# Using cached ml_dtypes-0.5.4-cp313-cp313-win_amd64.whl (212 kB)
# Downloading protobuf-7.34.1-cp310-abi3-win_amd64.whl (437 kB)
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached wheel-0.46.3-py3-none-any.whl (30 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading keras-3.14.0-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/1.6 MB 19.4 MB/s eta 0:00:00
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp313-cp313-win_amd64.whl (60 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp313-cp313-win_amd64.whl (337 kB)
# Downloading rich-14.3.4-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, termcolor, protobuf, optree, opt_einsum, ml_dtypes, mdurl, h5py, grpcio, google_pasta, gast, absl-py, markdown-it-py, astunparse, rich, keras, tensorflow
#
#    ----------------------------------------  0/21 [namex]
#    - --------------------------------------  1/21 [libclang]
#    - --------------------------------------  1/21 [libclang]
#    - --------------------------------------  1/21 [libclang]
#    --- ------------------------------------  2/21 [flatbuffers]
#    --- ------------------------------------  2/21 [flatbuffers]
#    --- ------------------------------------  2/21 [flatbuffers]
#    --- ------------------------------------  2/21 [flatbuffers]
#    ----- ----------------------------------  3/21 [wrapt]
#    ----- ----------------------------------  3/21 [wrapt]
#    ----- ----------------------------------  3/21 [wrapt]
#    ------- --------------------------------  4/21 [wheel]
#    ------- --------------------------------  4/21 [wheel]
#    ------- --------------------------------  4/21 [wheel]
#    ------- --------------------------------  4/21 [wheel]
#    ------- --------------------------------  4/21 [wheel]
#    ------- --------------------------------  4/21 [wheel]
#    --------- ------------------------------  5/21 [termcolor]
#    ----------- ----------------------------  6/21 [protobuf]
#    ----------- ----------------------------  6/21 [protobuf]
#    ----------- ----------------------------  6/21 [protobuf]
#    ----------- ----------------------------  6/21 [protobuf]
#    ----------- ----------------------------  6/21 [protobuf]
#    ----------- ----------------------------  6/21 [protobuf]
#    ------------- --------------------------  7/21 [optree]
#    ------------- --------------------------  7/21 [optree]
#    ------------- --------------------------  7/21 [optree]
#    --------------- ------------------------  8/21 [opt_einsum]
#    --------------- ------------------------  8/21 [opt_einsum]
#    --------------- ------------------------  8/21 [opt_einsum]
#    ----------------- ----------------------  9/21 [ml_dtypes]
#    ------------------- -------------------- 10/21 [mdurl]
#    -------------------- ------------------- 11/21 [h5py]
#    -------------------- ------------------- 11/21 [h5py]
#    -------------------- ------------------- 11/21 [h5py]
#    -------------------- ------------------- 11/21 [h5py]
#    -------------------- ------------------- 11/21 [h5py]
#    -------------------- ------------------- 11/21 [h5py]
#    ---------------------- ----------------- 12/21 [grpcio]
#    ---------------------- ----------------- 12/21 [grpcio]
#    ---------------------- ----------------- 12/21 [grpcio]
#    ---------------------- ----------------- 12/21 [grpcio]
#    ---------------------- ----------------- 12/21 [grpcio]
#    ---------------------- ----------------- 12/21 [grpcio]
#    ------------------------ --------------- 13/21 [google_pasta]
#    ------------------------ --------------- 13/21 [google_pasta]
#    -------------------------- ------------- 14/21 [gast]
#    -------------------------- ------------- 14/21 [gast]
#    ---------------------------- ----------- 15/21 [absl-py]
#    ---------------------------- ----------- 15/21 [absl-py]
#    ---------------------------- ----------- 15/21 [absl-py]
#    ------------------------------ --------- 16/21 [markdown-it-py]
#    ------------------------------ --------- 16/21 [markdown-it-py]
#    ------------------------------ --------- 16/21 [markdown-it-py]
#    ------------------------------ --------- 16/21 [markdown-it-py]
#    ------------------------------ --------- 16/21 [markdown-it-py]
#    ------------------------------ --------- 16/21 [markdown-it-py]
#    -------------------------------- ------- 17/21 [astunparse]
#    ---------------------------------- ----- 18/21 [rich]
#    ---------------------------------- ----- 18/21 [rich]
#    ---------------------------------- ----- 18/21 [rich]
#    ---------------------------------- ----- 18/21 [rich]
#    ---------------------------------- ----- 18/21 [rich]
#    ---------------------------------- ----- 18/21 [rich]
#    ---------------------------------- ----- 18/21 [rich]
#    ---------------------------------- ----- 18/21 [rich]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    ------------------------------------ --- 19/21 [keras]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    -------------------------------------- - 20/21 [tensorflow]
#    ---------------------------------------- 21/21 [tensorflow]
#
# Successfully installed absl-py-2.4.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.80.0 h5py-3.14.0 keras-3.14.0 libclang-18.1.1 markdown-it-py-4.0.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 protobuf-7.34.1 rich-14.3.4 tensorflow-2.21.0 termcolor-3.3.0 wheel-0.46.3 wrapt-2.1.2
# Note: you may need to restart the kernel to use updated packages.
# CPU times: total: 516 ms
# Wall time: 2min 43s
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Install SkLearn library for evaluation metrics

# %%
# %%time
# %pip install scikit-learn==1.7.0
# Out:
# Collecting scikit-learn==1.7.0
#   Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.22.0 in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from scikit-learn==1.7.0) (2.4.4)
# Collecting scipy>=1.8.0 (from scikit-learn==1.7.0)
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn==1.7.0)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.7.0)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.0-cp313-cp313-win_amd64.whl (10.7 MB)
#    ---------------------------------------- 0.0/10.7 MB ? eta -:--:--
#    ---------------- ----------------------- 4.5/10.7 MB 22.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.7/10.7 MB 27.1 MB/s eta 0:00:00
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#    -------- ------------------------------- 8.1/36.5 MB 37.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 16.0/36.5 MB 37.0 MB/s eta 0:00:01
#    ------------------------- -------------- 23.3/36.5 MB 36.5 MB/s eta 0:00:01
#    ------------------------------ --------- 27.5/36.5 MB 32.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 32.0/36.5 MB 29.9 MB/s eta 0:00:01
#    ---------------------------------------  36.4/36.5 MB 30.2 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 28.5 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
#
#    ---------------------------------------- 0/4 [threadpoolctl]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    -------------------- ------------------- 2/4 [joblib]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ------------------------------ --------- 3/4 [scikit-learn]
#    ---------------------------------------- 4/4 [scikit-learn]
#
# Successfully installed joblib-1.5.3 scikit-learn-1.7.0 scipy-1.17.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.
# CPU times: total: 62.5 ms
# Wall time: 38.2 s
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Library imports and setup
#
# Import essential libraries for data manipulation, visualization, and suppresses warnings for cleaner notebook output.

# %%
# %pip install tqdm
# Out:
# Collecting tqdm
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in d:\github\ibm-ai-capstone-project-with-deep-learning-\.venv\lib\site-packages (from tqdm) (0.4.6)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%time
import warnings
warnings.filterwarnings('ignore')

import os
import time
import httpx
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
# Out:
# CPU times: total: 0 ns
# Wall time: 20.5 μs

# %% [markdown]
# ### PyTorch library imports
#
# Import core PyTorch modules for model building, optimization, data loading, and functional utilities.

# %%
# %%time
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import torch.nn.functional as F

print("Imported libraries")
# Out:
# Imported libraries
# CPU times: total: 1.41 s
# Wall time: 1.82 s

# %% [markdown]
# ### TensorFlow/Keras library imports
#
# These imports set the environment variables to reduce TensorFlow logging noise and imports Keras modules for model building and training. They detect GPU availability for device assignment.

# %%
# %%time
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.initializers import HeUniform
from tensorflow.keras.callbacks import ModelCheckpoint

gpu_list = tf.config.list_physical_devices('GPU')
device = "gpu" if gpu_list != [] else "cpu"
print(f"Device available for training: {device}")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Device available for training: cpu
# CPU times: total: 15.6 ms
# Wall time: 1.13 s

# %% [markdown]
# ## Evaluation metrics
#
# The following metrics are used for evaluation of various AI/ML models:
#
# - Accuracy
# - Precision
# - Recall
# - F1 score
# - Confusion matrix
# - Receiver Operating Characteristic - Area Under Curve (ROC-AUC)
#
# You can read about their calculation methods and their significance for model performance below.

# %% [markdown]
# ### 1. Accuracy
#
# **Definition:**
# Accuracy is the proportion of correct predictions (both true positives and true negatives) among the total number of cases examined. In other words, it measures how often the classifier is correct overall.
#
# **Formula:**
# \[
# Accuracy = $\frac{TP + TN}{TP + TN + FP + FN}$
# \]
#
# - TP: True positives (correctly predicted positive cases)
# - TN: True negatives (correctly predicted negative cases)
# - FP: False positives (incorrectly predicted positive cases)
# - FN: False negatives (incorrectly predicted negative cases)
#
# **Significance:**
#
# Accuracy is intuitive and easy to interpret, making it a common first metric for model evaluation. However, it can be misleading if the dataset is imbalanced (i.e., one class is much more frequent than the other). This is because a model can achieve high accuracy by simply predicting the majority class.

# %% [markdown]
# ### 2. Precision
#
# **Definition:**
# Precision measures the proportion of positive predictions that are actually correct. It answers the question: "Of all the samples that the model predicted as positive, how many were truly positive?"
#
# **Formula:**
# \[
# Precision = $\frac{TP}{TP + FP}$
# \]
#
# **Significance:**
# Precision is crucial when the cost of a false positive is high. For example, in medical diagnosis, predicting a disease when it's not present (false positive) can lead to unnecessary treatments. In land classification, high precision means that when the model predicts a tile as agricultural, it is likely correct.

# %% [markdown]
# ### 3. Recall (sensitivity or true positive rate)
#
# **Definition:**
# Recall measures the proportion of actual positive cases that were correctly identified by the model. It answers: "Of all the true positive samples, how many did the model identify?"
#
# **Formula:**
# \[
# Recall = $\frac{TP}{TP + FN}$
# \]
#
# **Significance:**
# Recall is important when the cost of missing a positive case (false negative) is high. In land classification, high recall means the model is good at finding all the agricultural land, even if it sometimes mislabels non-agricultural land as agricultural.

# %% [markdown]
# ### 4. F1 score
#
# **Definition:**
# The F1 score is the harmonic mean of precision and recall. It provides a single metric that balances both concerns. It is especially useful when you need to find an equilibrium between precision and recall.
#
# **Formula:**
# \[
# F1 = $2 \times \frac{Precision \times Recall}{Precision + Recall}$
# \]
#
# **Significance:**
# The F1 score is especially valuable when the class distribution is uneven or when both false positives and false negatives are important. It penalizes extreme values, so a model with high precision but low recall (or vice versa) will have a lower F1 score.

# %% [markdown]
# ### 5. Confusion matrix
#
# **Definition:**
# A confusion matrix is a table that summarizes the performance of a classification algorithm. It displays the counts of true positives, false positives, true negatives, and false negatives.
#
# |               | Predicted positive | Predicted negative |
# |---------------|-------------------|-------------------|
# | Actual positive | True positive (TP) | False negative (FN) |
# | Actual negative | False positive (FP) | True negative (TN) |
#
# **Significance:**
# The confusion matrix provides a detailed breakdown of model errors and successes, helping you understand not just how often the model is right, but *how* it is wrong. This is crucial for diagnosing issues like class imbalance or systematic misclassification.

# %% [markdown]
# ### 6. ROC-AUC (Receiver operating characteristic - Area under curve)
#
# **Definition:**
# ROC-AUC measures the model's ability to distinguish between classes across all possible classification thresholds. The ROC curve plots the true positive rate (recall) against the false positive rate at various thresholds. The AUC (area under the curve) summarizes this performance in a single value between 0 and 1.
#
# **Significance:**
# A model with an ROC-AUC of 1.0 perfectly distinguishes between classes, while a value of 0.5 suggests random guessing. ROC-AUC is especially useful for imbalanced datasets and when you care about the ranking of predictions rather than their absolute values.

# %% [markdown]
# ## Import the evaluation metrics
#
# Here you define the functions to compute and print classification metrics including accuracy, precision, recall, F1 score, ROC-AUC, confusion matrix, and log loss. These functions support both Keras and PyTorch model outputs.

# %%
# %%time
from sklearn.metrics import (accuracy_score,
                             precision_score,
                             recall_score,
                             f1_score,
                             roc_curve, 
                             roc_auc_score,
                             log_loss,
                             classification_report,
                             confusion_matrix,
                             ConfusionMatrixDisplay,
                            )
from sklearn.preprocessing import label_binarize

# define a function to get the metrics comprehensively
def model_metrics(y_true, y_pred, y_prob, class_labels):
    metrics = {'Accuracy': accuracy_score(y_true, y_pred),
               'Precision': precision_score(y_true, y_pred),
               'Recall': recall_score(y_true, y_pred),
               'Loss': log_loss(y_true, y_prob),
               'F1 Score': f1_score(y_true, y_pred),
               'ROC-AUC': roc_auc_score(y_true, y_prob),
               'Confusion Matrix': confusion_matrix(y_true, y_pred),
               'Classification Report': classification_report(y_true, y_pred, target_names=class_labels, digits=4),
               "Class labels": class_labels
              }
    return metrics

#function to print the metrics
def print_metrics(y_true, y_pred, y_prob, class_labels, model_name):
    metrics = model_metrics(y_true, y_pred, y_prob, class_labels)
    print(f"Evaluation metrics for the \033[1m{model_name}\033[0m")
    print(f"Accuracy: {'':<1}{metrics["Accuracy"]:.4f}")
    print(f"ROC-AUC: {'':<2}{metrics["ROC-AUC"]:.4f}")
    print(f"Loss: {'':<5}{metrics["Loss"]:.4f}\n")
    print(f"Classification report:\n\n  {metrics["Classification Report"]}")
    print("========= Confusion Matrix =========")
    disp = ConfusionMatrixDisplay(confusion_matrix=metrics["Confusion Matrix"],
                                  display_labels=metrics["Class labels"])

    disp.plot()
    plt.show()
# Out:
# CPU times: total: 93.8 ms
# Wall time: 557 ms

# %% [markdown]
# ## Model download helper
#
# Now, define an asynchronous function to download model files from given URLs, if they are not already present locally.
# You use `httpx` for asynchronous HTTP requests with error handling.

# %%
async def download_model(url, model_path):
    if not os.path.exists(model_path):
        try:
            print(f"Downloading from {url}...")
            import httpx
            async with httpx.AsyncClient() as client:
                response = await client.get(url, follow_redirects=True)
                response.raise_for_status()
                with open(model_path, "wb") as f:
                    f.write(response.content)
            print(f"Successfully downloaded '{model_path}'.")
        except Exception as e:
            print(f"Download error: {e}")
    else:
        print(f"Model file already downloaded at: {model_path}")

# %% [markdown]
# ## Model paths and download
#
# In the cell below, you define the file paths and URLs for the Keras and PyTorch models and download them using the `download_model` function defined above.

# %%
data_dir = "."

keras_model_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/U-uPeyCyOQYh0GrZPGsqoQ/ai-capstone-keras-best-model-model.keras"
keras_model_name = "ai-capstone-keras-best-model-model_downloaded.keras"
keras_model_path = os.path.join(data_dir, keras_model_name)

pytorch_state_dict_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/8J2QEyQqD8x9zjrlnv6N7g/ai-capstone-pytorch-best-model-20250713.pth"
pytorch_state_dict_name = "ai_capstone_pytorch_best_model_state_dict_downloaded.pth"
pytorch_state_dict_path = os.path.join(data_dir, pytorch_state_dict_name)

await download_model(keras_model_url, keras_model_path)
await download_model(pytorch_state_dict_url, pytorch_state_dict_path)
# Out:
# Downloading from https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/U-uPeyCyOQYh0GrZPGsqoQ/ai-capstone-keras-best-model-model.keras...
# Successfully downloaded '.\ai-capstone-keras-best-model-model_downloaded.keras'.
# Downloading from https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/8J2QEyQqD8x9zjrlnv6N7g/ai-capstone-pytorch-best-model-20250713.pth...
# Successfully downloaded '.\ai_capstone_pytorch_best_model_state_dict_downloaded.pth'.

# %% [markdown]
# ## Dataset path and parameters
#
# Here, for downstream processing, you define
# 1. the dataset directory path
# 2. define image dimensions
# 3. number of channels
# 4. batch size
# 5. number of classes
# 6. class labels

# %%
dataset_path = os.path.join(data_dir, "images_dataSAT")
print(dataset_path)

img_w, img_h = 64, 64
n_channels = 3
batch_size = 128
num_classes = 2

agri_class_labels = ["non-agri", "agri"]
# Out:
# .\images_dataSAT

# %% [markdown]
# ## Keras model evaluation and prediction
#
# In this cell, you will:
# - Use `ImageDataGenerator` to rescale images.
# - Load test images from the dataset directory.
# - Load the saved Keras model using `tf.keras.models.load_model`.
# - Run predictions on the test set, collect predicted probabilities, predicted classes, and true labels.

# %%
# %%time

datagen = ImageDataGenerator(rescale=1./255)
prediction_generator = datagen.flow_from_directory(
    dataset_path,
    target_size=(img_w, img_h),
    batch_size=batch_size,
    class_mode="binary",
    shuffle=False
)

keras_model = tf.keras.models.load_model(keras_model_path)

steps = int(np.ceil(prediction_generator.samples / prediction_generator.batch_size))
batch_size = int(prediction_generator.batch_size)
print(f"Number of Steps: {steps} with batch size: {batch_size}")

all_preds_keras = []
all_probs_keras = []
all_labels_keras = []

for step_idx, step in enumerate(tqdm(range(steps), desc="Steps")):
    images, labels = next(prediction_generator)
    preds = keras_model.predict(images, verbose='0')
    all_probs_keras.extend(preds)
    preds = (preds > 0.5).astype(int).flatten()
    all_preds_keras.extend(preds)
    all_labels_keras.extend(labels)
# Out:
# Found 6000 images belonging to 2 classes.
# Number of Steps: 47 with batch size: 128
# Steps: 100%|██████████| 47/47 [01:07<00:00,  1.43s/it]
# CPU times: total: 1min 43s
# Wall time: 1min 16s

# %% [markdown]
# #### Question: What does the code **`preds > 0.5`** in line `preds = (preds > 0.5).astype(int).flatten()` do?

# %% [markdown]
# Please use the space below to write your answer.

# %% [markdown]
# It converts all predictions greater than 0.5 to True or assign to class 1. Rest of the predictions are False, assigned to class 0

# %% [markdown]
# Double-click **here** for the solution.
# <!--
# "It converts all predictions greater than 0.5 to True or assign to class 1. Rest of the predictions are False, assigned to class 0"
# -->

# %% [markdown]
# ## Keras metrics reporting

# %% [markdown]
# ### Task 1: Print the performance metrics for the Keras model using `print_metrics` function
#
# Print various performance metrics for the **Keras** model. You may use the previously defined metrics print function `print_metrics`.

# %%
## Please use the space below to write your answer
print_metrics(y_true = all_labels_keras,
              y_pred = all_preds_keras,
              y_prob = all_probs_keras,
              class_labels = agri_class_labels,
              model_name = "Keras Model"
             )
# Out:
# Evaluation metrics for the Keras Model
# Accuracy:  0.9925
# ROC-AUC:   1.0000
# Loss:      0.0247
#
# Classification report:
#
#                 precision    recall  f1-score   support
#
#     non-agri     0.9852    1.0000    0.9926      3000
#         agri     1.0000    0.9850    0.9924      3000
#
#     accuracy                         0.9925      6000
#    macro avg     0.9926    0.9925    0.9925      6000
# weighted avg     0.9926    0.9925    0.9925      6000
#
# ========= Confusion Matrix =========

# %% [markdown]
# Double-click **here** for the solution.
# <!--
# print_metrics(y_true = all_labels_keras,
#               y_pred = all_preds_keras,
#               y_prob = all_probs_keras,
#               class_labels = agri_class_labels,
#               model_name = "Keras Model"
#              )
#
# -->

# %% [markdown]
# #### Question: What is the significance of `f1 score`?

# %% [markdown]
# Please use the space below to write your answer.

# %% [markdown]
# It is useful when both false positives and false negatives are important

# %% [markdown]
# Double-click **here** for the solution.
# <!--
# "It is useful when both false positives and false negatives are important"
# -->

# %% [markdown]
# ## PyTorch model evaluation and prediction
#
# In this cell, you:
# - Set device for inference (GPU if available).
# - Define data transformations including resizing, normalization.
# - Load the dataset using `ImageFolder` and prepares a DataLoader.
# - Define the CNN architecture matching the saved state dict.
# - Load model weights.
# - Run inference on the test set, collecting predicted classes, probabilities, and true labels for metric calculation.

# %%
# %%time
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Processing inference on {device}")

train_transform = transforms.Compose([
    transforms.Resize((img_w, img_h)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
full_dataset = datasets.ImageFolder(dataset_path, transform=train_transform)
test_loader = DataLoader(full_dataset, batch_size=batch_size, shuffle=False)

model = nn.Sequential(
    nn.Conv2d(3, 32, 5, padding=2), nn.ReLU(),
    nn.MaxPool2d(2), nn.BatchNorm2d(32),
    nn.Conv2d(32, 64, 5, padding=2), nn.ReLU(), nn.MaxPool2d(2), nn.BatchNorm2d(64),
    nn.Conv2d(64, 128, 5, padding=2), nn.ReLU(), nn.MaxPool2d(2), nn.BatchNorm2d(128),
    nn.Conv2d(128, 256, 5, padding=2), nn.ReLU(), nn.MaxPool2d(2), nn.BatchNorm2d(256),
    nn.Conv2d(256, 512, 5, padding=2), nn.ReLU(), nn.MaxPool2d(2), nn.BatchNorm2d(512),
    nn.Conv2d(512, 1024, 5, padding=2), nn.ReLU(), nn.MaxPool2d(2), nn.BatchNorm2d(1024),
    nn.AdaptiveAvgPool2d(1), nn.Flatten(),
    nn.Linear(1024, 2048), nn.ReLU(), nn.BatchNorm1d(2048), nn.Dropout(0.4),
    nn.Linear(2048, num_classes)
).to(device)

print("Created model, now loading the weights from saved model state dict")
model.load_state_dict(torch.load(pytorch_state_dict_path))
print("Loaded model state dict, now getting predictions")

all_preds_pytorch = []
all_labels_pytorch = []
all_probs_pytorch = []


model.eval()
with torch.no_grad():
    for batch_idx, (images, labels) in enumerate(tqdm(test_loader, desc="Step")):
#    for images, labels in test_loader:
        images = images.to(device)
        outputs = model(images)
        preds = torch.argmax(outputs, dim=1)
        probs = F.softmax(outputs, dim=1)[:, 1]  # probability for class 1
        all_probs_pytorch.extend(probs.cpu())
        all_preds_pytorch.extend(preds.cpu().numpy().flatten())
        all_labels_pytorch.extend(labels.numpy())
# Out:
# Processing inference on cpu
# Created model, now loading the weights from saved model state dict
# Loaded model state dict, now getting predictions
# Step: 100%|██████████| 47/47 [00:21<00:00,  2.22it/s]
# CPU times: total: 1min 51s
# Wall time: 22.9 s

# %% [markdown]
# ## PyTorch metrics reporting

# %% [markdown]
# ### Task 2: Print the performance metrics for the PyTorch model using `print_metrics`
#
# Print various performance metrics for the PyTorch model. You may use the previously defined metrics print function `print_metrics`.

# %%
## Please use the space below to write your answer
print_metrics(y_true = all_labels_pytorch,
              y_pred = all_preds_pytorch,
              y_prob = all_probs_pytorch,
              class_labels = agri_class_labels,
              model_name = "PyTorch Model"
             )
# Out:
# Evaluation metrics for the PyTorch Model
# Accuracy:  0.9988
# ROC-AUC:   1.0000
# Loss:      0.0024
#
# Classification report:
#
#                 precision    recall  f1-score   support
#
#     non-agri     0.9993    0.9983    0.9988      3000
#         agri     0.9983    0.9993    0.9988      3000
#
#     accuracy                         0.9988      6000
#    macro avg     0.9988    0.9988    0.9988      6000
# weighted avg     0.9988    0.9988    0.9988      6000
#
# ========= Confusion Matrix =========

# %% [markdown]
# Double-click **here** for the solution.
# <!--
# print_metrics(y_true = all_labels_pytorch,
#               y_pred = all_preds_pytorch,
#               y_prob = all_probs_pytorch,
#               class_labels = agri_class_labels,
#               model_name = "PyTorch Model"
#              )
# -->

# %% [markdown]
# #### Question: What are the total number of false negatives in the `confusion matrix` in the PyTorch model evaluated above?

# %% [markdown]
# Please use the space below to write your answer.

# %% [markdown]
# Total Flase negatives are 2

# %% [markdown]
# Double-click **here** for the solution.
# <!--
# "Total Flase negatives are 5"
# -->

# %% [markdown]
# ## ROC curve plotting
#
# First, define a function to plot ROC curves for binary or multi-class classification using scikit-learn's `roc_curve` and `roc_auc_score`. It handles both single-class and multi-class cases by binarizing labels if needed.
#
# Next, plot the ROC curves for both the models.

# %%
def plot_roc(y_true, y_prob, model_name):
    n_classes = y_prob.shape[1] if y_prob.ndim > 1 else 1
    if n_classes == 1:
        fpr, tpr, _ = roc_curve(y_true, y_prob)
        auc = roc_auc_score(y_true, y_prob)
        plt.plot(fpr, tpr, label=f'{model_name} (AUC = {auc:.2f})')
    else:
        y_true_bin = label_binarize(y_true, classes=np.arange(n_classes))
        for i in range(n_classes):
            fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_prob[:, i])
            auc = roc_auc_score(y_true_bin[:, i], y_prob[:, i])
            plt.plot(fpr, tpr, label=f'{model_name} class {i} (AUC = {auc:.2f})')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend()

# %% [markdown]
# ### ROC curve plotting for both models
#
# Plot the ROC curves for both Keras and PyTorch models on the same figure for visual performance comparison.

# %%
plot_roc(np.array(all_labels_keras), np.array(all_probs_keras), "Keras Model")
plt.show()
plot_roc(np.array(all_labels_pytorch), np.array(all_probs_pytorch), "PyTorch Model")
plt.show()

# %% [markdown]
# ## Comparing model performance
#
# Now compare the performance of different models to understand which model would be the best performer for your land classification task.

# %%
# get the Keras model performance metrics
metrics_keras = model_metrics(all_labels_keras, all_preds_keras, all_probs_keras, agri_class_labels)

# get the PyTorch model performance metrics
metrics_pytorch = model_metrics(all_labels_pytorch, all_preds_pytorch, all_probs_pytorch, agri_class_labels)


# Display the comparison of metrics
print("{:<18} {:<15} {:<15}".format('\033[1m'+ 'Metric' + '\033[0m',
                                    'Keras Model', 
                                    'PyTorch Model'))

mertics_list = ['Accuracy', 'Precision', 'Recall', 'F1 Score', 'ROC-AUC']

for k in mertics_list:
    print("{:<18} {:<15.4f} {:<15.4f}".format('\033[1m'+k+'\033[0m',
                                              metrics_keras[k],
                                              metrics_pytorch[k]))
# Out:
# Metric     Keras Model     PyTorch Model
# Accuracy   0.9925          0.9988
# Precision  1.0000          0.9983
# Recall     0.9850          0.9993
# F1 Score   0.9924          0.9988
# ROC-AUC    1.0000          1.0000

# %% [markdown]
# ### Metric analysis
#
# The metrics for the pre-trained Keras and PyTorch models for evaluating the provided dataset are:
#
# - **Accuracy**
#     1. Keras: 0.9925
#     2. PyTorch: 0.9988
#
#     ===> Both models achieve exceptional accuracy, but the **PyTorch model makes fewer mistakes**.
#
# - **Precision**
#     1. Keras: 1.0000
#     2. PyTorch: 0.9983
#
#     ===> The **Keras** model perfectly **avoids false positives**, whereas the PyTorch model is slightly less perfect but still excellent.
#
# - **Recall**
#     1. Keras: 0.9850
#     2. PyTorch: 0.9993
#
#     ===> The **PyTorch** model is marginally better at **identifying all true positives**, capturing nearly all actual positive cases, while the Keras model misses a few.
#
# - **F1 Score**
#     1. PyTorch: 0.9988
#     2. Keras: 0.9924
#
#     ===> The F1 score, which balances precision and recall, favors the **PyTorch** model thanks to its **stronger recall**.
#
# - **ROC-AUC**
#     1. Keras: 1.0000
#     2. PyTorch: 1.0000
#
#     ===> Both models reach maximum possible **discrimination between classes**, indicating outstanding capability for binary classification.

# %% [markdown]
# ### **Model comparison: Key insights**
#
#
# **PyTorch model strengths**
#
#  - Achieves the highest scores in accuracy, recall, and F1, indicating extremely robust overall performance and near-perfect classification of positive cases
# - ROC-AUC of 1.0 shows perfect class separability
#
#
# **Keras model strengths**
#
# - Displays almost perfect precision every positive prediction made is correct
# - Also achieves perfect ROC-AUC, indicating outstanding discrimination ability
#
#
# **Common strength**
#
# - Both models deliver flawless ROC-AUC, suggesting both are highly effective for this classification task
#
#
# **Recommendations**
#
# Based on the scores from the uploaded pre-trained models:
#
# - The PyTorch model is preferable for applications where missing any positive instances is costly (higher recall)
# - The Keras model is optimal for scenarios where making any false positive error is unacceptable (higher precision).
#
#
# **Next**
#
# - Analyze the confusion matrices to investigate the errors.
# - Monitor real-world performance, as even marginal differences can become important in high-impact applications.
#
#
# **Summary**
#
# Both models excel in all evaluated metrics and would be highly reliable in production. The PyTorch model demonstrates a modest edge in recall and F1 score, while the Keras model maximizes precision. The choice between models should ultimately reflect the specific requirements and risk tolerance of your use case.

# %% [markdown]
# ## Save and download the notebook for **final project** submission and evaluation
#
# You will need to save and download the completed notebook for final project submission and evaluation.
# <br>For saving and downloading the completed notebook, please follow the steps given below:</br>
#
# <font size = 4>
#
# 1) **Complete** all the tasks and questions given in the notebook.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/nv4jHlPU5_R1q7ZJrZ69eg/DL0321EN-M1L1-Save-IPYNB-Screenshot-1.png" style="width:600px; border:0px solid black;">
#
# 2) **Save** the notebook.</style>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/9-WPWD4mW1d-RV5Il5otTg/DL0321EN-M1L1-Save-IPYNB-Screenshot-2.png" style="width:600px; border:0px solid black;">
#
# 3) Identify and right click on the **correct notebook file** in the left pane.</style>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/RUSRPw7NT6Sof94B7-9naQ/DL0321EN-M1L1-Save-IPYNB-Screenshot-3.png" style="width:600px; border:0px solid black;">
#
# 4) Click on **Download**.</style>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/HHry4GT-vhLEcRi1T_LHGg/DL0321EN-M1L1-Save-IPYNB-Screenshot-4.png" style="width:600px; border:0px solid black;">
#
# 5) Download and **Save** the Jupyter notebook file on your computer **for final submission**.</style>
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/hhsJbxc6R-T8_pXQGjMjvg/DL0321EN-M1L1-Save-IPYNB-Screenshot-5.png" style="width:600px; border:0px solid black;">
#   </font>

# %% [markdown]
# ## Conclusion
#
# Congratulations! You've successfully evaluated and compared two deep learning models, one using Keras and the other using the PyTorch framework.
#
# You learnt about a comprehensive workflow for comparing Keras and PyTorch models on the same dataset and got hands-on experience on:
# - data preparation
# - model loading
# - predicting dataset
# - metric computation
# - ROC visualization
# - Model performance comparison
#
# Using these framework independent metrics, you now know how to evaluate different models for their performance.

# %% [markdown]
# <h2>Author</h2>
#
# [Aman Aggarwal](https://www.linkedin.com/in/aggarwal-aman)
#
# Aman Aggarwal is a PhD working at the intersection of neuroscience, AI, and drug discovery. He specializes in quantitative microscopy and image processing.

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2025-07-14  | 1.0  | Aman  |  Created the lab |
#
# -->

# %% [markdown]
# © Copyright IBM Corporation. All rights reserved.
